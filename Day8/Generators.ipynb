# %% [markdown]
# Generators- a func that produces one output at a time  using yield keyword instead of returning all values
# -func state is preserved
# -generates values on the fly
# -memory efficint

# %%
# def generator():
#   for i in range(5):
#     yield i
# call=generator()
# print(next(call))
# print(next(call))
# next(call)

# or

gen=(x for x in range(5)) #also a generator
print(next(gen))
print(next(gen))
next(gen)
print(gen)
# Out:
# <generator object <genexpr> at 0x0000024FA61DE8E0>

# %%
# fibonacci
def fib(n):
  a=0
  b=1
  for i in range(n):
    yield a
    a,b=b,a+b
gen=fib(7)
for i in gen:
  print(i)
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
