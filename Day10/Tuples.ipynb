# %%
l = []
for i in range(5):
  l.append(input())
tup=tuple(l)
for i, val in enumerate(tup):
  print(i, val)
# Out:
# 0 Ram
# 1 Shyam
# 2 Gauri
# 3 Gaurika
# 4 Neha

# %%
l = []
for i in range(5):
  l.append(input())
tup=tuple(l)
for i in range(len(tup)-1, -1, -1):
  print(i, tup[i])
# Out:
# 4 5
# 3 4
# 2 3
# 1 2
# 0 1

# %%
empty_Set=set()
print(type(empty_Set))
# Out:
# <class 'set'>
