# %%
d={"name":"Ishita","age":22}
print(d.get("name"))
print(d.get("phone")) # returns None when not found
# print(d["phone"])  #gives error if not found
# Out:
# Ishita
# None

# %% [markdown]
# pop(), popitem(), clear()
# pop(<key>)- removes particular key, throws keyError if not found
# popitem()- removes last

# %%
student={}
student["name"]="Ishita"
student["age"]=25
student["gender"]="female"

student["age"]=22

student.pop("gender")

print(student.keys())

print(student.values())

for key,val in student.items():
  print(key,val)

stu_data={101:{"name":"Gauri","age":22}}

# %%
# cubes using dictionary comprehension
cubes={x:x**3 for x in [1,2,3,4]}
print(cubes)
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64}

# %%
# freq of chars
s="A dog jumps over a wall"
freq={}
for i in s:
  freq[i]+=1
print(freq)

# %%
temp=[30,31,32,40,45,34,22,24,26,36,21,43,35,38,39]
print(max(temp))
print(min(temp))
print(sum(temp)/len(temp))

# %%
lang={"Java","Python","C++","C","JS"}
print(sorted(lang))

# %%
l=[]
for i in range(8):
  l.append([0,i])
coord=tuple(l)
print(coord)

# %%
play1={"s1","s2","s3","s4"}
play2={"s3","s4","s5","s6"}
print(play1 & play2)
print(play1 - play2)
print(play2 - play1)

# %%
emp={101:"Ishita",102:"Shreya",104:"Priya"}
id=int(input())
print(emp.get(id))
